# %%
# %pip install pandas matplotlib seaborn
# Out:
# ...
#    ---------------------------------------- 8.3/8.3 MB 2.5 MB/s  0:00:03
# ...
#    ---------------------------------------- 2.3/2.3 MB 3.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 7.2/7.2 MB 2.4 MB/s  0:00:03
# ...
#
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def grafik_A_kelompok5(ax):
    agg = (df.groupby('Region')['avg_income (&)']
             .mean()
             .sort_values())

    colors = sns.color_palette('Purples_d', len(agg))
    ax.barh(agg.index, agg.values, color=colors, edgecolor='white')

    ax.set_title('Rata-rata Pendapatan per Kawasan Region',
                 fontsize=13, fontweight='bold', pad=12)
    ax.set_xlabel('Rata-rata avg_income (&)', fontsize=10)
    ax.set_ylabel('')

    for bar in ax.patches:
        ax.text(
            bar.get_width() + 50,
            bar.get_y() + bar.get_height() / 2,
            f'{bar.get_width():,.0f}',
            va='center', ha='left', fontsize=8
        )

    ax.xaxis.set_major_formatter(
        plt.FuncFormatter(lambda x, _: f'{x:,.0f}')
    )
    ax.spines[['top', 'right']].set_visible(False)
    ax.grid(axis='x', linestyle='--', alpha=0.4)

# %%
from textwrap import fill

def wrap_labels(labels, width=15):
    return [fill(str(label), width=width) for label in labels]

# %%
fig, ax = plt.subplots(figsize=(11, 6))
grafik_A_kelompok5(ax)
plt.tight_layout()
plt.savefig('grafik_A_kelompok5.png',
            dpi=150, bbox_inches='tight')
plt.show()
